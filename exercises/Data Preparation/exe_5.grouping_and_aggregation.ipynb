# %% [markdown]
# # Exercise: Grouping and Aggregation in Pandas
#
# In this exercise, you will practice **grouping and aggregating data** using the `mtcars` dataset.
# Follow the instructions in each question and write your code in the code cells provided.
#
# Remember: Grouping allows you to summarize data by subgroups and compute statistics such as mean, sum, min, or max.

# %% [markdown]
# ## Step 1: Load the Dataset
#
# **Task:** Load the `mtcars.csv` file into a pandas DataFrame and assign meaningful column names.
#
# Columns: `['car_names','mpg','cyl','disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear', 'carb']`
#
# Display the first 5 rows to verify.

# %%
# TODO: Import pandas and load the dataset
# import pandas as pd
# Read CSV and assign column names
# Display first 5 rows

# %% [markdown]
# ## Step 2: Group by Cylinders
#
# **Task:** Group the DataFrame by the `cyl` column.
# Do not compute anything yet; just create a grouped object.

# %%
# TODO: Group the DataFrame by 'cyl'
# grouped_cars =

# %% [markdown]
# ## Step 3: Compute Mean for Each Group
#
# **Task:** Compute the mean of all numeric columns for each cylinder group.
# Display the result.

# %%
# TODO: Compute mean for each group
# grouped_cars.mean(numeric_only=True)

# %% [markdown]
# ## Step 4: Insights from Grouping
#
# **Questions:**
# 1. Which cylinder group has the highest average miles per gallon (`mpg`)?
# 2. How does the average `hp` (horsepower) change as the number of cylinders increases?
# 3. Can you identify any trends in the weight (`wt`) column across cylinder groups?
#
# Write your answers in a markdown cell below.

# %% [markdown]
# ## Step 5: Optional Challenge
#
# Use the `agg()` method to compute **both the mean and max** of `mpg` and `hp` for each cylinder group.

# %%
# TODO: Use agg to compute mean and max of 'mpg' and 'hp'
# grouped_cars.agg(...)
