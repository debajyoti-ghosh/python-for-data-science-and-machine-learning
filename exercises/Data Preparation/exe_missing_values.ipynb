# %% [markdown]
# # Exercise 1 — Create a DataFrame with Missing Values
#
# Create a pandas DataFrame that satisfies the following conditions:
#
# - It must contain **at least 5 rows**
# - It must contain **at least 3 columns**
# - Some values must be **missing**, represented using `np.nan`
# - Suggested columns: `name`, `age`, `score`

# %% [markdown]
# # Exercise 2 — Detect Missing Values
#
# Using the DataFrame you created:
#
# - Use df.isnull() to return a boolean mask of missing values
# - Use df.notnull() to return non-missing value mask
# - Count the total missing values per column:

# %% [markdown]
# # Exercise 3 — Filter Rows with Missing Values
#
# Perform the following:
#
# - Select rows where a specific column (e.g., age) is missing

# %% [markdown]
# - Select rows where any column is missing

# %% [markdown]
# - Select rows where all values are missing

# %% [markdown]
# # Exercise 4 — Fill Missing Values
#
# Fill missing values in different ways:
# 1. Replace missing values with a constant (e.g., 0)
# 2. Forward fill (ffill)
# 3. Backward fill (bfill)
# 4. Fill using interpolation
# 5. Replace missing values in one specific column only
#
# Compare the results of each method.

# %% [markdown]
# # Exercise 5 — Drop Missing Values
#
# Perform the following:
# 1. Drop rows with any missing values
# 2. Drop rows where all values are missing
# 3. Drop columns that contain at least one missing value
# 4. Drop rows where less than 2 values are present
#
# Explain how these affect the DataFrame.

# %% [markdown]
# # Exercise 6 — Compute Statistics with Missing Values
#
# Calculate:
#
# 1. Column means normally
# 2. Column means ignoring NaN
# 3. Fill missing values with the column mean
#
# Observe how this changes the distribution.

# %% [markdown]
# # Exercise 7 — Realistic Cleaning Task
#
# Create a DataFrame representing student exam scores with random missing values.
#
# Your tasks:
#
# 1. Randomly insert missing values using np.nan
# 2. Replace missing values using interpolation
# 3. Drop rows where more than 50% values are missing
# 4. Normalize the scores between 0 and 1
# 5. Display the cleaned dataset

# %% [markdown]
# # Exercise 8 — Advanced Challenge
#
# Given a dataset with missing temperatures recorded hourly:
#
# 1. Fill missing values using:
#  - Linear interpolation
#  - Time-based interpolation
# 2. Plot before-and-after using matplotlib (optional)
# 3. Explain why interpolation is useful for continuous data

# %% [markdown]
# # Exercise 9 — Replace Missing Categorical Values
#
# Given a column containing missing categories:
# - Replace missing values with the mode (most frequent category)
# - Replace missing values with a new category "Unknown"
#
# Compare which method is more appropriate and why.

# %% [markdown]
# # Exercise 10 — Optional Mini Project
#
# Download any small dataset (CSV) with missing values (Iris, Titanic, etc.) and perform:
# - Missing value detection
# - Visualisation of missing values (heatmap optional)
# - Imputation
# - Cleaning
# -Summary report of choices and reasoning
#
# This can be submitted as a student assignment.
