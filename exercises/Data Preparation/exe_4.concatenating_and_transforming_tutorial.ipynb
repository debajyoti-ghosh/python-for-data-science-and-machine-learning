# %% [markdown]
# # Exercises: Concatenating and Transforming Data with pandas
#
# The following exercises are designed to help you **practice and reinforce** the concepts covered in this notebook:
# - Concatenating DataFrames
# - Dropping and adding data
# - Resetting indices
# - Sorting data
#
# Try to solve each exercise **before looking at the solution**. These tasks mirror real-world data preparation steps commonly used in analytics and data science workflows.

# %% [markdown]
# ## Exercise 1: Create DataFrames
#
# 1. Create a DataFrame called `df_a` with **20 values** arranged in **5 rows and 4 columns** using NumPy.
# 2. Create a second DataFrame called `df_b` with **10 values** arranged in **5 rows and 2 columns**.
# 3. Display both DataFrames.

# %%
# Your code here

# %% [markdown]
# ## Exercise 2: Concatenate by Columns
#
# 1. Concatenate `df_a` and `df_b` **column-wise**.
# 2. Ensure the concatenation is performed using the **row index**.
# 3. Observe how pandas aligns rows when indices match.

# %%
# Your code here

# %% [markdown]
# ## Exercise 3: Concatenate by Rows
#
# 1. Concatenate `df_a` and `df_b` **row-wise**.
# 2. What happens to missing columns?
# 3. Explain the appearance of NaN values in the result.

# %%
# Your code here

# %% [markdown]
# ## Exercise 4: Dropping Data
#
# Using `df_a`:
# 1. Drop the rows at index positions **1 and 3**.
# 2. Drop the columns at index positions **0 and 2**.
# 3. Display the results after each operation.

# %%
# Your code here

# %% [markdown]
# ## Exercise 5: Adding a New Variable
#
# 1. Create a `Series` named `new_feature` containing values from **100 to 104**.
# 2. Join this Series to `df_a` as a new column.
# 3. Verify that the data is aligned using the row index.

# %%
# Your code here

# %% [markdown]
# ## Exercise 6: Index Handling During Concatenation
#
# 1. Concatenate the updated DataFrame from Exercise 5 with itself.
# 2. First, keep the original index (`ignore_index=False`).
# 3. Then, repeat using `ignore_index=True`.
# 4. Compare the index values in both results.

# %%
# Your code here

# %% [markdown]
# ## Exercise 7: Sorting Data
#
# 1. Sort `df_a` by the values in **column index 1**.
# 2. Perform the sort in **descending order**.
# 3. Verify that all columns are reordered consistently.

# %%
# Your code here

# %% [markdown]
# ## Challenge Exercise (Optional)
#
# Simulate a real-world scenario:
#
# 1. Create one DataFrame representing **customer IDs and names**.
# 2. Create another DataFrame representing **customer IDs and addresses**.
# 3. Concatenate the two DataFrames so that each customer has both name and address.
# 4. Drop any unnecessary columns.
# 5. Sort the final table by customer ID.
#
# This exercise combines **concatenation, transformation, and sorting** in one workflow.

# %%
# Your code here
