# %% [markdown]
# # Applied Machine Learning: Starter Problem (Interactive Exercise)
#
# In this exercise, you'll prepare the Iris dataset, train a decision tree classifier, and evaluate its performance. Hints are provided in collapsible sections for each step.

# %% [markdown]
# ## Step 1: Import Libraries
#
# Import pandas for data manipulation, and scikit-learn modules for machine learning.
#
# <details>
# <summary>Hint</summary>
# Use `import pandas as pd`, `from sklearn.model_selection import train_test_split`, `from sklearn.tree import DecisionTreeClassifier`, and `from sklearn import metrics`.
# </details>

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Step 2: Load the Iris Dataset
#
# Read the CSV file into a pandas DataFrame.
#
# <details>
# <summary>Hint</summary>
# Use `pd.read_csv(address)` where `address` is the path to the CSV. Then use `.head()` to view the first rows.
# </details>

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Step 3: Check Unique Species
#
# Find the unique species labels in the dataset.
#
# <details>
# <summary>Hint</summary>
# Use `dataset['Species'].unique()` to get the unique species.
# </details>

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Step 4: Separate Features and Labels
#
# Separate input features `X` and target labels `y`.
#
# <details>
# <summary>Hint</summary>
# - Features are columns 1-4: `dataset.iloc[:, 1:5]`
# - Labels are column 5: `dataset.iloc[:, 5]`
# </details>

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Step 5: Split Dataset into Training and Test Sets
#
# Use 70% of the data for training and 30% for testing.
#
# <details>
# <summary>Hint</summary>
# Use `train_test_split(X, y, test_size=0.3, random_state=0)`.
# Assign outputs to `X_train, X_test, y_train, y_test`.
# </details>

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Step 6: Train Decision Tree Classifier
#
# <details>
# <summary>Hint</summary>
# Create a classifier with `clf = DecisionTreeClassifier()` and fit using `clf.fit(X_train, y_train)`.
# </details>

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Step 7: Make Predictions
#
# Predict species for the test set.
#
# <details>
# <summary>Hint</summary>
# Use `y_predict = clf.predict(X_test)`.
# </details>

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Step 8: Evaluate Model Accuracy
#
# <details>
# <summary>Hint</summary>
# Use `metrics.accuracy_score(y_test, y_predict)` and print the result.
# </details>

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Solutions (Collapsed)
#
# <details>
# <summary>Click to view solutions</summary>
#
# ```python
# import pandas as pd
# from sklearn.model_selection import train_test_split
# from sklearn.tree import DecisionTreeClassifier
# from sklearn import metrics
#
# address = '/workspaces/python-for-data-science-and-machine-learning-essential-training-part-1-3006708/data/iris.csv'
# dataset = pd.read_csv(address)
# dataset.head()
#
# dataset['Species'].unique()
#
# X = dataset.iloc[:, 1:5]
# y = dataset.iloc[:, 5]
#
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
#
# clf = DecisionTreeClassifier()
# clf.fit(X_train, y_train)
#
# y_predict = clf.predict(X_test)
#
# accuracy = metrics.accuracy_score(y_test, y_predict)
# print("Accuracy:", accuracy)
# ```
# </details>
