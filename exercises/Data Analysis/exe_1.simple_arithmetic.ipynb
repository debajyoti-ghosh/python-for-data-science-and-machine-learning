# %% [markdown]
# # NumPy Simple Arithmetic — Interactive Exercises
#
# This notebook helps you **practice arithmetic operations using NumPy arrays**.
#
# 📌 **Instructions**:
# - Read each task carefully
# - Try to write the code yourself
# - Use the **collapsible hints** only if needed
# - Check your answers in the **collapsed solutions section at the end**

# %% [markdown]
# ## Exercise 1 — Import NumPy and Set Print Precision
#
# **Task:**
# 1. Import NumPy as `np`
# 2. Set NumPy to display only **two decimal places**
#
# <details>
# <summary>💡 Hint</summary>
# Use `np.set_printoptions()` with the `precision` argument.
# </details>

# %% [markdown]
# ## Exercise 2 — Create a 1D NumPy Array
#
# **Task:**
# Create a NumPy array named `a` containing values from **1 to 6**.
#
# <details>
# <summary>💡 Hint</summary>
# Use `np.array()` and pass a Python list.
# </details>

# %% [markdown]
# ## Exercise 3 — Create a 2D Array (Matrix)
#
# **Task:**
# Create a matrix `b` with the following structure:
#
# ```
# [[10, 20, 30],
#  [40, 50, 60]]
# ```
#
# <details>
# <summary>💡 Hint</summary>
# Use nested lists inside `np.array()`.
# </details>

# %% [markdown]
# ## Exercise 4 — Generate Random Numbers
#
# **Task:**
# 1. Set NumPy's random seed to `25`
# 2. Create an array `c` containing **6 random values** scaled by `36`
#
# <details>
# <summary>💡 Hint</summary>
# Use `np.random.seed()` and `np.random.randn()`.
# </details>

# %% [markdown]
# ## Exercise 5 — Create a Sequential Array
#
# **Task:**
# Create an array `d` containing numbers from **1 to 34**.
#
# <details>
# <summary>💡 Hint</summary>
# `np.arange(start, stop)` excludes the stop value.
# </details>

# %% [markdown]
# ## Exercise 6 — Scalar Multiplication
#
# **Task:**
# Multiply every element of array `a` by `10`.
#
# <details>
# <summary>💡 Hint</summary>
# NumPy supports direct arithmetic with scalars.
# </details>

# %% [markdown]
# ## Exercise 7 — Element-wise Addition
#
# **Task:**
# Add arrays `c` and `a` element by element.
#
# <details>
# <summary>💡 Hint</summary>
# Arrays must have the same shape.
# </details>

# %% [markdown]
# ## Exercise 8 — Subtraction, Multiplication, and Division
#
# **Task:**
# Perform the following operations:
# - `c - a`
# - `c * a`
# - `c / a`
#
# <details>
# <summary>💡 Hint</summary>
# All operations are element-wise by default in NumPy.
# </details>

# %% [markdown]
# # ✅ Solutions (Self-Check — Expand Only After Attempting)
#
# ```python
# import numpy as np
# np.set_printoptions(precision=2)
#
# a = np.array([1, 2, 3, 4, 5, 6])
#
# b = np.array([[10, 20, 30], [40, 50, 60]])
#
# np.random.seed(25)
# c = 36 * np.random.randn(6)
#
# d = np.arange(1, 35)
#
# a * 10
# c + a
# c - a
# c * a
# c / a
# ```
#
# 🎯 **Well done!** You have practiced the most common arithmetic patterns used in NumPy.
