# %% [markdown]
# # 🧪 Exercise: Generating Summary Statistics with Pandas
#
# In this exercise notebook, you will practice generating **descriptive statistics** using `pandas`.
#
# You will:
# - Explore numeric summaries (mean, median, sum, max)
# - Analyze distribution statistics (standard deviation, variance)
# - Use `describe()` for fast exploratory data analysis
#
# 👉 Try to solve each step **before opening the hint**.
# 👉 At the end, use the **collapsed solution** to self-check.

# %% [markdown]
# ## Step 0: Setup
#
# Run the following cell to load the required libraries and dataset.

# %%
import numpy as np
import pandas as pd

address = '/workspaces/python-for-data-science-and-machine-learning-essential-training-part-1-3006708/data/mtcars.csv'
cars = pd.read_csv(address)
cars.columns = ['car_names','mpg','cyl','disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear', 'carb']

cars.head()

# %% [markdown]
# ## Step 1: Column-wise Sum
#
# **Task:**
# Calculate the **sum of each numeric column** in the dataset.
#
# <details>
# <summary>💡 Hint</summary>
#
# Use the `DataFrame.sum()` method.
# </details>

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Step 2: Row-wise Sum
#
# **Task:**
# Calculate the sum of values **row-wise**, using only numeric columns.
#
# <details>
# <summary>💡 Hint</summary>
#
# Use `axis=1` and `numeric_only=True`.
# </details>

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Step 3: Median Values
#
# **Task:**
# Find the **median** of each numeric variable.
#
# <details>
# <summary>💡 Hint</summary>
#
# Use `DataFrame.median()` with numeric-only data.
# </details>

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Step 4: Mean Values
#
# **Task:**
# Compute the **mean (average)** of each numeric column.
#
# <details>
# <summary>💡 Hint</summary>
#
# Use the `mean()` method.
# </details>

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Step 5: Maximum Values
#
# **Task:**
# Identify the **maximum value** for each variable.
#
# <details>
# <summary>💡 Hint</summary>
#
# Use `DataFrame.max()`.
# </details>

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Step 6: Locate Maximum MPG
#
# **Task:**
# Find the **row index** where the highest `mpg` value occurs.
#
# <details>
# <summary>💡 Hint</summary>
#
# Select the column first, then use `idxmax()`.
# </details>

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Step 7: Standard Deviation
#
# **Task:**
# Calculate the **standard deviation** for all numeric variables.
#
# <details>
# <summary>💡 Hint</summary>
#
# Use `std()`.
# </details>

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Step 8: Variance
#
# **Task:**
# Compute the **variance** of each numeric variable.
#
# <details>
# <summary>💡 Hint</summary>
#
# Variance is calculated using `var()`.
# </details>

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Step 9: Frequency Counts
#
# **Task:**
# Count how many cars fall into each `gear` category.
#
# <details>
# <summary>💡 Hint</summary>
#
# Use `value_counts()` on the `gear` column.
# </details>

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Step 10: Full Statistical Summary
#
# **Task:**
# Generate a **complete descriptive statistics table** for the dataset.
#
# <details>
# <summary>💡 Hint</summary>
#
# Use `describe()`.
# </details>

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## ✅ Collapsed Solution (Self-Check)
#
# <details>
# <summary>🔍 Click to reveal full solution</summary>
#
# ```python
# # Step 1
# cars.sum()
#
# # Step 2
# cars.sum(axis=1, numeric_only=True)
#
# # Step 3
# cars.median(numeric_only=True)
#
# # Step 4
# cars.mean(numeric_only=True)
#
# # Step 5
# cars.max()
#
# # Step 6
# cars.mpg.idxmax()
#
# # Step 7
# cars.std(numeric_only=True)
#
# # Step 8
# cars.var(numeric_only=True)
#
# # Step 9
# cars.gear.value_counts()
#
# # Step 10
# cars.describe()
# ```
# </details>
