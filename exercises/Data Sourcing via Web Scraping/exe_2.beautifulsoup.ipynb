# %% [markdown]
# # Web Scraping with Python and BeautifulSoup - Interactive Exercise
#
# In this interactive exercise, you will learn how to use BeautifulSoup to parse HTML and extract useful data. Each exercise includes a collapsible hint and a collapsed solution for self-checking.

# %% [markdown]
# ## Exercise 1: Check Python Version
# Before starting with BeautifulSoup, make sure your Python version is 3.10 or above.

# %%
# TODO: Print Python version

# %% [markdown]
# <details>
# <summary>Hint</summary>
# Use the `sys` module: `import sys` and `print(sys.version)`
# </details>

# %% [markdown]
# <details>
# <summary>Solution</summary>
# ```python
# import sys
# print(sys.version)
# ```
# </details>

# %% [markdown]
# ## Exercise 2: Import BeautifulSoup
# Import the BeautifulSoup class from the `bs4` package.

# %%
# TODO: Import BeautifulSoup

# %% [markdown]
# <details>
# <summary>Hint</summary>
# Use: `from bs4 import BeautifulSoup`
# </details>

# %% [markdown]
# <details>
# <summary>Solution</summary>
# ```python
# from bs4 import BeautifulSoup
# ```
# </details>

# %% [markdown]
# ## Exercise 3: Create a BeautifulSoup Object
# Parse the following HTML string into a BeautifulSoup object.

# %%
html_doc = '<html><head><title>IoT Articles</title></head><body><p class="title"><b>2018 Trends: Best New IoT Device Ideas</b></p></body></html>'
# TODO: Parse html_doc with html.parser and store in soup

# %% [markdown]
# <details>
# <summary>Hint</summary>
# Use: `soup = BeautifulSoup(html_doc, 'html.parser')`
# </details>

# %% [markdown]
# <details>
# <summary>Solution</summary>
# ```python
# soup = BeautifulSoup(html_doc, 'html.parser')
# print(soup)
# ```
# </details>

# %% [markdown]
# ## Exercise 4: Access Tag Name
# Retrieve the tag name of the first <p> tag in the HTML.

# %%
# TODO: Access the first <p> tag and print its name

# %% [markdown]
# <details>
# <summary>Hint</summary>
# Use: `tag = soup.p` and `tag.name`
# </details>

# %% [markdown]
# <details>
# <summary>Solution</summary>
# ```python
# tag = soup.p
# print(tag.name)
# ```
# </details>

# %% [markdown]
# ## Exercise 5: Access Tag Attributes
# Retrieve and modify the class attribute of the <p> tag.

# %%
# TODO: Print class attribute of <p> tag
# TODO: Add a new attribute 'id'='intro'
# TODO: Delete the 'class' attribute

# %% [markdown]
# <details>
# <summary>Hint</summary>
# Access attributes with `tag['class']`, add with `tag['id'] = 'intro'`, delete with `del tag['class']`
# </details>

# %% [markdown]
# <details>
# <summary>Solution</summary>
# ```python
# print(tag['class'])
# tag['id'] = 'intro'
# print(tag.attrs)
# del tag['class']
# print(tag.attrs)
# ```
# </details>

# %% [markdown]
# ## Exercise 6: Navigate the Parse Tree
# Access the `title` tag and its content in the HTML document.

# %%
# TODO: Print the title tag and its text

# %% [markdown]
# <details>
# <summary>Hint</summary>
# Use: `soup.title` and `soup.title.string`
# </details>

# %% [markdown]
# <details>
# <summary>Solution</summary>
# ```python
# print(soup.title)
# print(soup.title.string)
# ```
# </details>
