# %% [markdown]
# # Python Requests for Automating Data Collection
#
# This notebook is an interactive exercise for practicing HTTP requests using Python's `requests` library and comparing text sequences using `difflib`. Each step includes a collapsible hint. Solutions are provided at the end for self-checking.

# %% [markdown]
# ## 1. Import the `requests` library
#
# Exercise: Import the `requests` library which allows you to make HTTP requests.
#
# <details>
# <summary>Hint</summary>
# Use `import requests` to import the library.
# </details>

# %%
# Write your code here

# %% [markdown]
# ## 2. Make a GET request
#
# Exercise: Use `requests.get()` to retrieve data from `https://www.python.org`.
#
# <details>
# <summary>Hint</summary>
# response = requests.get('https://www.python.org')
# Check the response by printing it to see the status code.
# </details>

# %%
# Write your code here

# %% [markdown]
# ## 3. Inspect Response Headers
#
# Exercise: Print the response headers returned by the server.
#
# <details>
# <summary>Hint</summary>
# Use `response.headers` to view the headers metadata.
# </details>

# %%
# Write your code here

# %% [markdown]
# ## 4. Check Content Type
#
# Exercise: Print the content type of the response.
#
# <details>
# <summary>Hint</summary>
# Access the content type using `response.headers['Content-Type']`.
# </details>

# %%
# Write your code here

# %% [markdown]
# ## 5. Access Response Content
#
# Exercise: Retrieve the content of the response in bytes.
#
# <details>
# <summary>Hint</summary>
# Use `response.content` to get the content.
# </details>

# %%
# Write your code here

# %% [markdown]
# ## 6. Import `difflib` for Comparing Text
#
# Exercise: Import the `difflib` library to compare sequences of text.
#
# <details>
# <summary>Hint</summary>
# Use `import difflib`.
# </details>

# %%
# Write your code here

# %% [markdown]
# ## 7. Create Two Text Sequences
#
# Exercise: Create two sequences to compare.
#
# <details>
# <summary>Hint</summary>
# flines = 'Hello. How are you? I am fine.'
# glines = 'How are you, Lillian? I am doing well.'
# </details>

# %%
# Write your code here

# %% [markdown]
# ## 8. Compare the Text Sequences
#
# Exercise: Use `difflib.Differ` to compare the two sequences and print the differences.
#
# <details>
# <summary>Hint</summary>
# d = difflib.Differ()
# diff = d.compare(flines, glines)
# for line in diff:
#     print(line)
# </details>

# %%
# Write your code here

# %% [markdown]
# ## ✅ Collapsed Solutions
#
# <details>
# <summary>Click to reveal all solutions</summary>
#
# ```python
# import requests
# response = requests.get('https://www.python.org')
# print(response)
# print(response.headers)
# print(response.headers['Content-Type'])
# print(response.content)
#
# import difflib
# flines = 'Hello. How are you? I am fine.'
# glines = 'How are you, Lillian? I am doing well.'
# d = difflib.Differ()
# diff = d.compare(flines, glines)
# for line in diff:
#     print(line)
# ```
# </details>
